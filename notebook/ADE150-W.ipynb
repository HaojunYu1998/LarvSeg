# %%
COCO = [
    'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train',
    'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep',
    'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard',
    'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard',
    'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork',
    'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange',
    'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair',
    'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv',
    'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave',
    'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase',
    'scissors', 'teddy bear', 'hair drier', 'toothbrush', 'banner',
    'blanket', 'branch', 'bridge', 'building-other', 'bush', 'cabinet',
    'cage', 'cardboard', 'carpet', 'ceiling-other', 'ceiling-tile',
    'cloth', 'clothes', 'clouds', 'counter', 'cupboard', 'curtain',
    'desk-stuff', 'dirt', 'door-stuff', 'fence', 'floor-marble',
    'floor-other', 'floor-stone', 'floor-tile', 'floor-wood',
    'flower', 'fog', 'food-other', 'fruit', 'furniture-other', 'grass',
    'gravel', 'ground-other', 'hill', 'house', 'leaves', 'light', 'mat',
    'metal', 'mirror-stuff', 'moss', 'mountain', 'mud', 'napkin', 'net',
    'paper', 'pavement', 'pillow', 'plant-other', 'plastic', 'platform',
    'playingfield', 'railing', 'railroad', 'river', 'road', 'rock', 'roof',
    'rug', 'salad', 'sand', 'sea', 'shelf', 'sky-other', 'skyscraper',
    'snow', 'solid-other', 'stairs', 'stone', 'straw', 'structural-other',
    'table', 'tent', 'textile-other', 'towel', 'tree', 'vegetable',
    'wall-brick', 'wall-concrete', 'wall-other', 'wall-panel',
    'wall-stone', 'wall-tile', 'wall-wood', 'water-other', 'waterdrops',
    'window-blind', 'window-other', 'wood'
]
CLASSES150 = (
        'wall', 'building', 'sky', 'floor', 'tree', 'ceiling', 'road', 'bed',
        'windowpane', 'grass', 'cabinet', 'sidewalk', 'person', 'earth',
        'door', 'table', 'mountain', 'plant', 'curtain', 'chair', 'car',
        'water', 'painting', 'sofa', 'shelf', 'house', 'sea', 'mirror', 'rug',
        'field', 'armchair', 'seat', 'fence', 'desk', 'rock', 'wardrobe',
        'lamp', 'bathtub', 'railing', 'cushion', 'base', 'box', 'column',
        'signboard', 'chest of drawers', 'counter', 'sand', 'sink',
        'skyscraper', 'fireplace', 'refrigerator', 'grandstand', 'path',
        'stairs', 'runway', 'case', 'pool table', 'pillow', 'screen door',
        'stairway', 'river', 'bridge', 'bookcase', 'blind', 'coffee table',
        'toilet', 'flower', 'book', 'hill', 'bench', 'countertop', 'stove',
        'palm', 'kitchen island', 'computer', 'swivel chair', 'boat', 'bar',
        'arcade machine', 'hovel', 'bus', 'towel', 'light', 'truck', 'tower',
        'chandelier', 'awning', 'streetlight', 'booth', 'television receiver',
        'airplane', 'dirt track', 'apparel', 'pole', 'land', 'bannister',
        'escalator', 'ottoman', 'bottle', 'buffet', 'poster', 'stage', 'van',
        'ship', 'fountain', 'conveyer belt', 'canopy', 'washer', 'plaything',
        'swimming pool', 'stool', 'barrel', 'basket', 'waterfall', 'tent',
        'bag', 'minibike', 'cradle', 'oven', 'ball', 'food', 'step', 'tank',
        'trade name', 'microwave', 'pot', 'animal', 'bicycle', 'lake',
        'dishwasher', 'screen', 'blanket', 'sculpture', 'hood', 'sconce',
        'vase', 'traffic light', 'tray', 'ashcan', 'fan', 'pier', 'crt screen',
        'plate', 'monitor', 'bulletin board', 'shower', 'radiator', 'glass',
        'clock', 'flag')

processed_c171_classes = (
    "person",
    "bicycle",
    "car",
    "motorcycle",
    "airplane",
    "bus",
    "train",
    "truck",
    "boat",
    "traffic light",
    "fire hydrant",
    "stop sign",
    "parking meter",
    "bench",
    "bird",
    "cat",
    "dog",
    "horse",
    "sheep",
    "cow",
    "elephant",
    "bear",
    "zebra",
    "giraffe",
    "backpack",
    "umbrella",
    "handbag",
    "tie",
    "suitcase",
    "frisbee",
    "skis",
    "snowboard",
    "sports ball",
    "kite",
    "baseball bat",
    "baseball glove",
    "skateboard",
    "surfboard",
    "tennis racket",
    "bottle",
    "glass",
    "cup",
    "fork",
    "knife",
    "spoon",
    "bowl",
    "banana",
    "apple",
    "sandwich",
    "orange",
    "broccoli",
    "carrot",
    "hot dog",
    "pizza",
    "donut",
    "cake",
    "chair",
    "couch",
    "potted plant",
    "bed",
    "dining table",
    "toilet",
    "television receiver",
    "laptop",
    "mouse",
    "remote",
    "keyboard",
    "cell phone",
    "microwave",
    "oven",
    "toaster",
    "sink",
    "refrigerator",
    "book",
    "clock",
    "vase",
    "scissors",
    "teddy bear",
    "hair drier",
    "toothbrush",
    "banner",
    "blanket",
    "branch",
    "bridge",
    "building",
    "bush",
    "cabinet",
    "cage",
    "cardboard",
    "carpet",
    "ceiling",
    "ceiling",
    "cloth",
    "clothes",
    "clouds",
    "counter",
    "cupboard",
    "curtain",
    "desk",
    "dirt track",
    "door",
    "fence",
    "floor",
    "floor",
    "floor",
    "floor",
    "floor",
    "flower",
    "fog",
    "food",
    "fruit",
    "furniture",
    "grass",
    "gravel",
    "ground",
    "hill",
    "house",
    "leaves",
    "light",
    "mat",
    "metal",
    "mirror",
    "moss",
    "mountain",
    "mud",
    "napkin",
    "net",
    "paper",
    "pavement",
    "pillow",
    "plant",
    "plastic",
    "platform",
    "playingfield",
    "railing",
    "railroad",
    "river",
    "road",
    "rock",
    "roof",
    "rug",
    "salad",
    "sand",
    "sea",
    "shelf",
    "sky",
    "skyscraper",
    "snow",
    "solid",
    "stairs",
    "stone",
    "straw",
    "structural",
    "table",
    "tent",
    "textile",
    "towel",
    "tree",
    "vegetable",
    "wall",
    "wall",
    "wall",
    "wall",
    "wall",
    "wall",
    "wall",
    "water",
    "waterdrops",
    "blind",
    "windowpane",
    "wood",
)
# # processed_coco = [x.split("-")[0] for x in COCO]
# all_cls = list(set(processed_c171_classes)| set(CLASSES150))
# novel_cls = list(set(CLASSES150) - set(processed_c171_classes))
# base_cls = list(set(CLASSES150) & set(processed_c171_classes))
# len(base_cls), len(novel_cls), len(all_cls)
# import json

# json.dump(all_cls, open("../files/ade150ucoco.json", "w"))

# %%
cityscapes = ('road', 'sidewalk', 'building', 'wall', 'fence', 'pole',
               'traffic light', 'traffic sign', 'vegetation', 'terrain', 'sky',
               'person', 'rider', 'car', 'truck', 'bus', 'train', 'motorcycle',
               'bicycle')
novel_cls = list(set(CLASSES150) - set(cityscapes))
base_cls = list(set(CLASSES150) & set(cityscapes))

def _log(metric):
    import numpy as np
    metrics = [x.strip() for x in metric.split("\n")]
    ious = {}
    accs = {}
    for i in range(len(metrics)):
        k, iou, acc = metrics[i].split("|")[1:-1]
        ious[k.strip()] = float(iou.strip())
        accs[k.strip()] = float(acc.strip())
    ious_base = [v for k, v in ious.items() if k in base_cls]
    ious_novel = [v for k, v in ious.items() if k in novel_cls]
    accs_base = [v for k, v in accs.items() if k in base_cls]
    accs_novel = [v for k, v in accs.items() if k in novel_cls]
    print(f"seen: mIoU {np.mean(ious_base):.2f}, mAcc {np.mean(accs_base):.2f}")
    print(f"unseen: mIoU {np.mean(ious_novel):.2f}, mAcc {np.mean(accs_novel):.2f}")

# %%
_log("""|         wall        | 35.67 | 45.03 |
|       building      | 42.73 | 53.31 |
|         sky         | 54.35 | 90.46 |
|        floor        | 32.73 | 54.29 |
|         tree        | 38.84 |  72.1 |
|       ceiling       | 39.07 | 64.39 |
|         road        | 51.34 | 62.51 |
|         bed         | 46.31 | 75.65 |
|      windowpane     | 36.18 | 51.98 |
|        grass        | 32.16 | 39.11 |
|       cabinet       | 33.36 | 40.89 |
|       sidewalk      |  6.68 |  7.47 |
|        person       | 25.02 | 95.29 |
|        earth        |  4.81 |  5.33 |
|         door        | 26.03 | 33.85 |
|        table        | 19.82 | 27.12 |
|       mountain      | 29.85 |  42.0 |
|        plant        |  23.5 | 33.87 |
|       curtain       | 54.28 | 76.48 |
|        chair        | 25.26 | 46.27 |
|         car         | 41.63 | 90.42 |
|        water        |  8.91 |  11.1 |
|       painting      | 36.51 | 74.46 |
|         sofa        | 38.16 | 47.33 |
|        shelf        |  13.9 |  16.2 |
|        house        |  3.73 |  4.08 |
|         sea         | 31.74 | 53.21 |
|        mirror       | 34.67 | 52.88 |
|         rug         | 37.58 | 40.49 |
|        field        |  4.21 |  4.38 |
|       armchair      | 13.68 | 15.28 |
|         seat        | 38.19 | 48.67 |
|        fence        | 14.77 | 18.21 |
|         desk        | 17.31 |  25.1 |
|         rock        | 24.84 | 39.48 |
|       wardrobe      | 30.88 | 33.92 |
|         lamp        | 10.03 | 64.89 |
|       bathtub       | 42.82 |  58.8 |
|       railing       |  12.2 | 14.15 |
|       cushion       | 31.96 |  48.1 |
|         base        |  1.09 |  1.22 |
|         box         | 10.97 | 13.77 |
|        column       | 21.85 | 29.94 |
|      signboard      | 21.96 | 35.45 |
|   chest of drawers  | 22.05 | 29.66 |
|       counter       |  8.39 |  8.9  |
|         sand        | 23.16 | 23.85 |
|         sink        | 24.64 |  64.3 |
|      skyscraper     | 16.88 |  19.1 |
|      fireplace      | 35.07 | 76.56 |
|     refrigerator    | 54.34 | 63.58 |
|      grandstand     | 25.67 | 39.41 |
|         path        |  1.26 |  1.28 |
|        stairs       |  0.28 |  0.29 |
|        runway       | 25.72 | 29.05 |
|         case        | 29.84 | 35.64 |
|      pool table     | 63.69 | 95.79 |
|        pillow       |  2.31 |  2.45 |
|     screen door     | 12.11 | 12.51 |
|       stairway      | 20.66 | 26.11 |
|        river        |  1.54 |  1.68 |
|        bridge       | 16.37 | 21.41 |
|       bookcase      | 16.31 | 19.93 |
|        blind        | 23.78 | 25.21 |
|     coffee table    | 10.55 | 12.12 |
|        toilet       | 32.44 | 82.24 |
|        flower       | 16.02 | 43.39 |
|         book        | 24.44 | 51.98 |
|         hill        |  1.38 |  1.43 |
|        bench        | 19.73 | 31.63 |
|      countertop     |  0.57 |  0.57 |
|        stove        | 40.17 | 53.07 |
|         palm        | 29.55 | 58.51 |
|    kitchen island   |  0.15 |  0.15 |
|       computer      | 36.41 | 43.54 |
|     swivel chair    |  34.6 |  51.0 |
|         boat        | 24.68 | 43.84 |
|         bar         | 17.25 | 19.39 |
|    arcade machine   |  5.48 |  5.51 |
|        hovel        |  5.01 |  5.07 |
|         bus         | 68.48 | 89.51 |
|        towel        | 35.26 | 65.59 |
|        light        |  4.57 |  17.1 |
|        truck        |  30.0 | 35.26 |
|        tower        |  1.88 |  2.29 |
|      chandelier     | 25.11 | 83.56 |
|        awning       | 12.87 | 14.83 |
|     streetlight     | 14.82 | 40.84 |
|        booth        |  1.0  |  1.01 |
| television receiver | 29.61 | 59.41 |
|       airplane      |  17.4 | 48.46 |
|      dirt track     |  0.0  |  0.0  |
|       apparel       | 30.33 | 45.09 |
|         pole        |  5.93 |  7.39 |
|         land        |  0.05 |  0.05 |
|      bannister      |  2.18 |  2.71 |
|      escalator      |  2.19 |  2.24 |
|       ottoman       | 19.31 | 22.68 |
|        bottle       | 19.25 | 71.24 |
|        buffet       | 14.81 | 15.14 |
|        poster       |  5.84 |  6.15 |
|        stage        |  5.9  | 15.36 |
|         van         | 12.69 | 14.49 |
|         ship        |  1.19 |  1.2  |
|       fountain      |  4.57 |  4.79 |
|    conveyer belt    | 46.85 | 48.25 |
|        canopy       |  0.36 |  0.37 |
|        washer       | 38.75 | 45.02 |
|      plaything      | 19.32 | 29.94 |
|    swimming pool    | 27.09 | 28.42 |
|        stool        | 29.37 | 41.48 |
|        barrel       | 41.81 | 53.78 |
|        basket       | 18.29 | 26.05 |
|      waterfall      | 33.16 | 56.87 |
|         tent        | 80.63 | 86.19 |
|         bag         |  2.97 |  3.12 |
|       minibike      | 37.54 | 82.91 |
|        cradle       |  35.9 | 86.01 |
|         oven        |  0.09 |  0.09 |
|         ball        | 24.46 | 42.18 |
|         food        |  14.9 | 16.38 |
|         step        |  0.0  |  0.0  |
|         tank        |  14.9 | 15.23 |
|      trade name     |  3.61 |  4.0  |
|      microwave      | 47.59 | 70.85 |
|         pot         | 16.82 |  21.1 |
|        animal       |  22.8 | 26.57 |
|       bicycle       |  24.2 | 92.13 |
|         lake        |  0.7  |  0.73 |
|      dishwasher     |  0.23 |  0.23 |
|        screen       |  55.5 | 80.68 |
|       blanket       |  0.0  |  0.0  |
|      sculpture      | 26.06 | 47.41 |
|         hood        | 24.31 | 28.77 |
|        sconce       |  8.29 | 23.93 |
|         vase        |  2.65 |  3.31 |
|    traffic light    |  9.42 | 15.36 |
|         tray        |  5.26 |  9.45 |
|        ashcan       | 16.33 | 18.32 |
|         fan         | 17.76 | 39.53 |
|         pier        |  0.38 |  0.65 |
|      crt screen     |  1.53 |  1.55 |
|        plate        | 27.66 |  53.4 |
|       monitor       |  2.07 |  2.11 |
|    bulletin board   |  4.78 |  5.38 |
|        shower       |  4.92 |  8.06 |
|       radiator      | 35.16 | 37.06 |
|        glass        |  8.32 |  9.17 |
|        clock        |  4.89 | 21.94 |
|         flag        | 10.96 | 37.52 |""")
# Out:
# seen: mIoU 31.56, mAcc 54.03
# unseen: mIoU 19.91, mAcc 30.98

# %% [markdown]
# # Sample Images for Visualization

# %%
with open("/mnt/haojun/itpsea4data/dataset/imagenet22k_azcopy/ImageNet130.txt", "r") as f:
    lines = f.readlines()

# %%
images = {}
for line in lines:
    img_id = line.strip()
    cls_id = img_id.split("_")[0]
    if cls_id not in images:
        images[cls_id] = []
    images[cls_id].append(img_id)

# %%
import numpy as np
with open("/mnt/haojun/itpsea4data/dataset/imagenet22k_azcopy/ImageNet130_vis20.txt", "w") as f:
    for cls_id in images:
        imgs = images[cls_id]
        inds = np.random.choice(range(len(imgs)), size=20, replace=False)
        for ind in inds:
            print(imgs[ind], file=f)

# %%
a150_classes = (
    'wall', 'building', 'sky', 'floor', 'tree', 'ceiling', 'road', 'bed',
    'windowpane', 'grass', 'cabinet', 'sidewalk', 'person', 'earth',
    'door', 'table', 'mountain', 'plant', 'curtain', 'chair', 'car',
    'water', 'painting', 'sofa', 'shelf', 'house', 'sea', 'mirror', 'rug',
    'field', 'armchair', 'seat', 'fence', 'desk', 'rock', 'wardrobe',
    'lamp', 'bathtub', 'railing', 'cushion', 'base', 'box', 'column',
    'signboard', 'chest of drawers', 'counter', 'sand', 'sink',
    'skyscraper', 'fireplace', 'refrigerator', 'grandstand', 'path',
    'stairs', 'runway', 'case', 'pool table', 'pillow', 'screen door',
    'stairway', 'river', 'bridge', 'bookcase', 'blind', 'coffee table',
    'toilet', 'flower', 'book', 'hill', 'bench', 'countertop', 'stove',
    'palm', 'kitchen island', 'computer', 'swivel chair', 'boat', 'bar',
    'arcade machine', 'hovel', 'bus', 'towel', 'light', 'truck', 'tower',
    'chandelier', 'awning', 'streetlight', 'booth', 'television receiver',
    'airplane', 'dirt track', 'apparel', 'pole', 'land', 'bannister',
    'escalator', 'ottoman', 'bottle', 'buffet', 'poster', 'stage', 'van',
    'ship', 'fountain', 'conveyer belt', 'canopy', 'washer', 'plaything',
    'swimming pool', 'stool', 'barrel', 'basket', 'waterfall', 'tent',
    'bag', 'minibike', 'cradle', 'oven', 'ball', 'food', 'step', 'tank',
    'trade name', 'microwave', 'pot', 'animal', 'bicycle', 'lake',
    'dishwasher', 'screen', 'blanket', 'sculpture', 'hood', 'sconce',
    'vase', 'traffic light', 'tray', 'ashcan', 'fan', 'pier', 'crt screen',
    'plate', 'monitor', 'bulletin board', 'shower', 'radiator', 'glass',
    'clock', 'flag')

c171_classes = (
    'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train',
    'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep',
    'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard',
    'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard',
    'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork',
    'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange',
    'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair',
    'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv',
    'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave',
    'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase',
    'scissors', 'teddy bear', 'hair drier', 'toothbrush', 'banner',
    'blanket', 'branch', 'bridge', 'building-other', 'bush', 'cabinet',
    'cage', 'cardboard', 'carpet', 'ceiling-other', 'ceiling-tile',
    'cloth', 'clothes', 'clouds', 'counter', 'cupboard', 'curtain',
    'desk-stuff', 'dirt', 'door-stuff', 'fence', 'floor-marble',
    'floor-other', 'floor-stone', 'floor-tile', 'floor-wood',
    'flower', 'fog', 'food-other', 'fruit', 'furniture-other', 'grass',
    'gravel', 'ground-other', 'hill', 'house', 'leaves', 'light', 'mat',
    'metal', 'mirror-stuff', 'moss', 'mountain', 'mud', 'napkin', 'net',
    'paper', 'pavement', 'pillow', 'plant-other', 'plastic', 'platform',
    'playingfield', 'railing', 'railroad', 'river', 'road', 'rock', 'roof',
    'rug', 'salad', 'sand', 'sea', 'shelf', 'sky-other', 'skyscraper',
    'snow', 'solid-other', 'stairs', 'stone', 'straw', 'structural-other',
    'table', 'tent', 'textile-other', 'towel', 'tree', 'vegetable',
    'wall-brick', 'wall-concrete', 'wall-other', 'wall-panel',
    'wall-stone', 'wall-tile', 'wall-wood', 'water-other', 'waterdrops',
    'window-blind', 'window-other', 'wood')

processed_c171_classes = (
    'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train',
    'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep',
    'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard',
    'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard',
    'surfboard', 'tennis racket', 'bottle', 'glass', 'cup', 'fork',
    'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange',
    'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair',
    'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'television receiver',
    'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave',
    'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase',
    'scissors', 'teddy bear', 'hair drier', 'toothbrush', 'banner',
    'blanket', 'branch', 'bridge', 'building', 'bush', 'cabinet',
    'cage', 'cardboard', 'carpet', 'ceiling', 'ceiling',
    'cloth', 'clothes', 'clouds', 'counter', 'cupboard', 'curtain',
    'desk', 'dirt track', 'door', 'fence', 'floor',
    'floor', 'floor', 'floor', 'floor',
    'flower', 'fog', 'food', 'fruit', 'furniture', 'grass',
    'gravel', 'ground', 'hill', 'house', 'leaves', 'light', 'mat',
    'metal', 'mirror', 'moss', 'mountain', 'mud', 'napkin', 'net',
    'paper', 'pavement', 'pillow', 'plant', 'plastic', 'platform',
    'playingfield', 'railing', 'railroad', 'river', 'road', 'rock', 'roof',
    'rug', 'salad', 'sand', 'sea', 'shelf', 'sky', 'skyscraper',
    'snow', 'solid', 'stairs', 'stone', 'straw', 'structural',
    'table', 'tent', 'textile', 'towel', 'tree', 'vegetable',
    'wall', 'wall', 'wall', 'wall',
    'wall', 'wall', 'wall', 'water', 'waterdrops',
    'blind', 'windowpane', 'wood')

a150_c171 = list(set(a150_classes) - set(processed_c171_classes))
inter_cls = list(set(processed_c171_classes) & set(a150_classes))
c171_a150 = [c171_classes[i] for i in range(len(c171_classes)) if processed_c171_classes[i] not in inter_cls]

# %%
import json

json.dump(a150_c171, open("a150-c171.json", "w"))

# %%
import json

json.dump(c171_a150, open("c171-a150.json", "w"))

# %%
c171ua150 = list(set(a150_classes) | set(c171_classes))
import json

json.dump(c171_a150, open("coco171uade150.json", "w"))

# %%
ade_splits = [
    [1, 3, 6, 8, 10, 13, 17, 22, 23, 29, 33, 38, 41, 50, 51, 56, 67, 70, 71, 74, 77, 81, 92, 93, 98,
    101, 102, 103, 110, 113, 119, 121, 126, 127, 130, 136, 147, 149],

    [0, 10, 21, 27, 28, 29, 34, 40, 42, 43, 51, 57, 58, 65, 66, 68, 69, 73, 76, 78, 85, 88, 90, 100,
    105, 110, 111, 112, 113, 114, 117, 123, 124, 132, 134, 139, 142, 146],

    [0, 5, 9, 15, 16, 21, 24, 25, 27, 32, 34, 35, 38, 39, 55, 70, 76, 85, 95, 96, 98, 100, 106, 109,
    111, 118, 119, 124, 128, 132, 134, 135, 136, 138, 140, 141, 143, 144],
    
    [5, 11, 13, 16, 21, 24, 26, 32, 35, 42, 53, 56, 60, 61, 63, 64, 68, 70, 75, 82, 91, 93, 94, 99, 100,
    105, 111, 115, 118, 121, 122, 130, 132, 135, 137, 138, 141, 143]
]

def _log_splits(metric, split):
    import numpy as np
    metrics = [x.strip() for x in metric.split("\n")]
    ious_novel = []
    accs_novel = []
    ious_base = []
    accs_base = []

    for i in range(len(metrics)):
        k, iou, acc = metrics[i].split("|")[1:-1]
        if i in ade_splits[split]:
            ious_novel.append(float(iou.strip()))
            accs_novel.append(float(acc.strip()))
        else:
            ious_base.append(float(iou.strip()))
            accs_base.append(float(acc.strip()))
    print(f"seen: mIoU {np.mean(ious_base):.2f}, mAcc {np.mean(accs_base):.2f}")
    print(f"unseen: mIoU {np.mean(ious_novel):.2f}, mAcc {np.mean(accs_novel):.2f}")

# %%
a = """|         wall        | 71.23 | 88.91 |
|       building      | 59.64 | 62.62 |
|         sky         | 91.46 | 97.98 |
|        floor        | 66.94 | 71.59 |
|         tree        | 68.48 | 89.52 |
|       ceiling       | 79.55 | 92.95 |
|         road        | 59.18 | 67.98 |
|         bed         |  85.8 | 93.47 |
|      windowpane     | 40.55 | 47.49 |
|        grass        |  66.4 | 88.82 |
|       cabinet       |  38.1 |  40.6 |
|       sidewalk      | 48.99 | 89.48 |
|        person       | 72.75 | 93.17 |
|        earth        |  31.2 | 39.25 |
|         door        | 39.98 | 60.24 |
|        table        |  49.7 | 74.87 |
|       mountain      | 56.78 |  71.0 |
|        plant        | 35.85 | 45.62 |
|       curtain       | 67.42 | 82.07 |
|        chair        | 50.15 |  69.8 |
|         car         | 73.71 | 93.93 |
|        water        | 57.85 | 78.92 |
|       painting      | 44.51 |  71.3 |
|         sofa        | 48.05 | 54.28 |
|        shelf        | 41.77 | 61.84 |
|        house        | 46.03 |  72.1 |
|         sea         | 58.01 | 70.17 |
|        mirror       | 57.31 | 69.12 |
|         rug         | 53.56 | 82.88 |
|        field        | 21.55 | 26.61 |
|       armchair      | 38.08 | 64.78 |
|         seat        | 54.86 | 78.04 |
|        fence        | 35.82 | 62.06 |
|         desk        | 21.15 | 24.69 |
|         rock        | 41.55 | 63.73 |
|       wardrobe      | 47.54 | 67.51 |
|         lamp        | 50.64 | 74.32 |
|       bathtub       | 79.02 |  87.5 |
|       railing       | 21.69 | 25.81 |
|       cushion       |  47.8 | 68.98 |
|         base        | 31.79 | 52.37 |
|         box         | 14.27 | 18.75 |
|        column       | 38.53 | 55.13 |
|      signboard      | 23.24 | 61.99 |
|   chest of drawers  |  26.7 | 66.34 |
|       counter       | 39.56 |  65.6 |
|         sand        | 45.09 | 61.24 |
|         sink        |  59.3 | 76.51 |
|      skyscraper     | 44.53 | 75.23 |
|      fireplace      | 69.45 |  82.4 |
|     refrigerator    | 61.39 | 70.43 |
|      grandstand     | 35.12 | 59.06 |
|         path        | 21.55 |  33.0 |
|        stairs       | 25.73 | 47.15 |
|        runway       | 67.17 | 87.68 |
|         case        | 42.34 | 48.67 |
|      pool table     | 79.15 | 93.61 |
|        pillow       |  51.2 | 63.18 |
|     screen door     | 59.67 |  68.6 |
|       stairway      | 34.51 | 50.16 |
|        river        |  8.39 | 16.56 |
|        bridge       | 64.78 | 83.28 |
|       bookcase      | 38.58 |  66.4 |
|        blind        | 47.23 | 68.71 |
|     coffee table    | 54.43 | 77.85 |
|        toilet       | 77.75 | 88.65 |
|        flower       | 34.18 | 60.94 |
|         book        | 36.71 | 48.48 |
|         hill        |  9.76 | 13.42 |
|        bench        | 39.07 | 49.02 |
|      countertop     | 38.89 | 53.12 |
|        stove        | 26.21 | 30.63 |
|         palm        | 45.77 | 67.16 |
|    kitchen island   | 35.02 | 82.66 |
|       computer      | 41.86 | 52.13 |
|     swivel chair    | 43.09 | 69.52 |
|         boat        |  45.2 | 75.48 |
|         bar         | 28.76 | 32.36 |
|    arcade machine   | 73.56 | 78.45 |
|        hovel        | 28.55 |  29.0 |
|         bus         | 61.05 | 93.03 |
|        towel        | 51.16 | 77.09 |
|        light        | 31.02 | 34.63 |
|        truck        | 26.48 | 54.15 |
|        tower        | 23.33 | 44.89 |
|      chandelier     |  57.5 | 77.45 |
|        awning       | 12.08 | 57.89 |
|     streetlight     | 12.52 | 37.17 |
|        booth        | 45.49 | 54.55 |
| television receiver |  65.0 | 79.17 |
|       airplane      | 53.36 | 68.05 |
|      dirt track     |  1.16 |  6.43 |
|       apparel       | 27.78 | 42.97 |
|         pole        |  3.49 |  7.99 |
|         land        |  0.09 |  0.19 |
|      bannister      |  7.2  | 16.92 |
|      escalator      | 36.69 | 54.31 |
|       ottoman       |  43.3 | 55.88 |
|        bottle       | 11.68 | 24.42 |
|        buffet       | 38.56 | 52.23 |
|        poster       | 19.04 | 31.76 |
|        stage        | 11.96 | 21.53 |
|         van         |  1.14 |  1.65 |
|         ship        | 23.25 | 29.31 |
|       fountain      | 27.07 | 28.22 |
|    conveyer belt    | 54.18 | 94.05 |
|        canopy       |  34.1 | 46.97 |
|        washer       | 71.71 | 77.62 |
|      plaything      | 29.53 | 50.28 |
|    swimming pool    | 61.07 | 71.06 |
|        stool        | 19.98 | 25.88 |
|        barrel       | 36.95 | 82.46 |
|        basket       | 31.53 | 45.24 |
|      waterfall      | 50.88 | 65.34 |
|         tent        | 89.62 | 96.97 |
|         bag         | 18.13 | 23.44 |
|       minibike      | 58.48 | 82.11 |
|        cradle       | 66.93 | 96.07 |
|         oven        | 16.63 | 54.05 |
|         ball        | 26.73 | 66.08 |
|         food        | 46.63 | 57.86 |
|         step        |  0.86 |  0.98 |
|         tank        | 46.96 |  61.0 |
|      trade name     | 22.59 | 42.03 |
|      microwave      | 60.81 | 75.81 |
|         pot         |  35.9 | 45.16 |
|        animal       | 53.13 | 68.55 |
|       bicycle       |  7.74 | 44.45 |
|         lake        | 41.21 | 53.07 |
|      dishwasher     | 30.32 | 80.03 |
|        screen       | 54.96 | 86.65 |
|       blanket       |  4.06 |  4.53 |
|      sculpture      | 49.32 |  71.6 |
|         hood        |  45.0 |  72.7 |
|        sconce       | 20.69 | 24.07 |
|         vase        | 30.94 | 41.72 |
|    traffic light    |  3.85 |  8.78 |
|         tray        |  6.05 |  9.62 |
|        ashcan       | 28.79 | 62.06 |
|         fan         | 47.81 | 60.17 |
|         pier        | 25.73 | 42.47 |
|      crt screen     | 10.33 | 19.71 |
|        plate        |  47.1 | 73.09 |
|       monitor       | 44.41 | 68.72 |
|    bulletin board   | 31.24 | 42.07 |
|        shower       |  2.19 |  4.03 |
|       radiator      | 54.81 | 66.19 |
|        glass        |  6.36 |  8.22 |
|        clock        | 21.04 | 27.11 |
|         flag        | 14.05 | 41.06 |"""

_log_splits(a, 0)
# Out:
# seen: mIoU 43.23, mAcc 61.45
# unseen: mIoU 32.10, mAcc 43.61
