# %%
COCO = [
    'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train',
    'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep',
    'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard',
    'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard',
    'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork',
    'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange',
    'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair',
    'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv',
    'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave',
    'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase',
    'scissors', 'teddy bear', 'hair drier', 'toothbrush', 'banner',
    'blanket', 'branch', 'bridge', 'building-other', 'bush', 'cabinet',
    'cage', 'cardboard', 'carpet', 'ceiling-other', 'ceiling-tile',
    'cloth', 'clothes', 'clouds', 'counter', 'cupboard', 'curtain',
    'desk-stuff', 'dirt', 'door-stuff', 'fence', 'floor-marble',
    'floor-other', 'floor-stone', 'floor-tile', 'floor-wood',
    'flower', 'fog', 'food-other', 'fruit', 'furniture-other', 'grass',
    'gravel', 'ground-other', 'hill', 'house', 'leaves', 'light', 'mat',
    'metal', 'mirror-stuff', 'moss', 'mountain', 'mud', 'napkin', 'net',
    'paper', 'pavement', 'pillow', 'plant-other', 'plastic', 'platform',
    'playingfield', 'railing', 'railroad', 'river', 'road', 'rock', 'roof',
    'rug', 'salad', 'sand', 'sea', 'shelf', 'sky-other', 'skyscraper',
    'snow', 'solid-other', 'stairs', 'stone', 'straw', 'structural-other',
    'table', 'tent', 'textile-other', 'towel', 'tree', 'vegetable',
    'wall-brick', 'wall-concrete', 'wall-other', 'wall-panel',
    'wall-stone', 'wall-tile', 'wall-wood', 'water-other', 'waterdrops',
    'window-blind', 'window-other', 'wood'
]
CLASSES150 = (
        'wall', 'building', 'sky', 'floor', 'tree', 'ceiling', 'road', 'bed',
        'windowpane', 'grass', 'cabinet', 'sidewalk', 'person', 'earth',
        'door', 'table', 'mountain', 'plant', 'curtain', 'chair', 'car',
        'water', 'painting', 'sofa', 'shelf', 'house', 'sea', 'mirror', 'rug',
        'field', 'armchair', 'seat', 'fence', 'desk', 'rock', 'wardrobe',
        'lamp', 'bathtub', 'railing', 'cushion', 'base', 'box', 'column',
        'signboard', 'chest of drawers', 'counter', 'sand', 'sink',
        'skyscraper', 'fireplace', 'refrigerator', 'grandstand', 'path',
        'stairs', 'runway', 'case', 'pool table', 'pillow', 'screen door',
        'stairway', 'river', 'bridge', 'bookcase', 'blind', 'coffee table',
        'toilet', 'flower', 'book', 'hill', 'bench', 'countertop', 'stove',
        'palm', 'kitchen island', 'computer', 'swivel chair', 'boat', 'bar',
        'arcade machine', 'hovel', 'bus', 'towel', 'light', 'truck', 'tower',
        'chandelier', 'awning', 'streetlight', 'booth', 'television receiver',
        'airplane', 'dirt track', 'apparel', 'pole', 'land', 'bannister',
        'escalator', 'ottoman', 'bottle', 'buffet', 'poster', 'stage', 'van',
        'ship', 'fountain', 'conveyer belt', 'canopy', 'washer', 'plaything',
        'swimming pool', 'stool', 'barrel', 'basket', 'waterfall', 'tent',
        'bag', 'minibike', 'cradle', 'oven', 'ball', 'food', 'step', 'tank',
        'trade name', 'microwave', 'pot', 'animal', 'bicycle', 'lake',
        'dishwasher', 'screen', 'blanket', 'sculpture', 'hood', 'sconce',
        'vase', 'traffic light', 'tray', 'ashcan', 'fan', 'pier', 'crt screen',
        'plate', 'monitor', 'bulletin board', 'shower', 'radiator', 'glass',
        'clock', 'flag')

processed_c171_classes = (
    "person",
    "bicycle",
    "car",
    "motorcycle",
    "airplane",
    "bus",
    "train",
    "truck",
    "boat",
    "traffic light",
    "fire hydrant",
    "stop sign",
    "parking meter",
    "bench",
    "bird",
    "cat",
    "dog",
    "horse",
    "sheep",
    "cow",
    "elephant",
    "bear",
    "zebra",
    "giraffe",
    "backpack",
    "umbrella",
    "handbag",
    "tie",
    "suitcase",
    "frisbee",
    "skis",
    "snowboard",
    "sports ball",
    "kite",
    "baseball bat",
    "baseball glove",
    "skateboard",
    "surfboard",
    "tennis racket",
    "bottle",
    "glass",
    "cup",
    "fork",
    "knife",
    "spoon",
    "bowl",
    "banana",
    "apple",
    "sandwich",
    "orange",
    "broccoli",
    "carrot",
    "hot dog",
    "pizza",
    "donut",
    "cake",
    "chair",
    "couch",
    "potted plant",
    "bed",
    "dining table",
    "toilet",
    "television receiver",
    "laptop",
    "mouse",
    "remote",
    "keyboard",
    "cell phone",
    "microwave",
    "oven",
    "toaster",
    "sink",
    "refrigerator",
    "book",
    "clock",
    "vase",
    "scissors",
    "teddy bear",
    "hair drier",
    "toothbrush",
    "banner",
    "blanket",
    "branch",
    "bridge",
    "building",
    "bush",
    "cabinet",
    "cage",
    "cardboard",
    "carpet",
    "ceiling",
    "ceiling",
    "cloth",
    "clothes",
    "clouds",
    "counter",
    "cupboard",
    "curtain",
    "desk",
    "dirt track",
    "door",
    "fence",
    "floor",
    "floor",
    "floor",
    "floor",
    "floor",
    "flower",
    "fog",
    "food",
    "fruit",
    "furniture",
    "grass",
    "gravel",
    "ground",
    "hill",
    "house",
    "leaves",
    "light",
    "mat",
    "metal",
    "mirror",
    "moss",
    "mountain",
    "mud",
    "napkin",
    "net",
    "paper",
    "pavement",
    "pillow",
    "plant",
    "plastic",
    "platform",
    "playingfield",
    "railing",
    "railroad",
    "river",
    "road",
    "rock",
    "roof",
    "rug",
    "salad",
    "sand",
    "sea",
    "shelf",
    "sky",
    "skyscraper",
    "snow",
    "solid",
    "stairs",
    "stone",
    "straw",
    "structural",
    "table",
    "tent",
    "textile",
    "towel",
    "tree",
    "vegetable",
    "wall",
    "wall",
    "wall",
    "wall",
    "wall",
    "wall",
    "wall",
    "water",
    "waterdrops",
    "blind",
    "windowpane",
    "wood",
)
# # processed_coco = [x.split("-")[0] for x in COCO]
# all_cls = list(set(processed_c171_classes)| set(CLASSES150))
# novel_cls = list(set(CLASSES150) - set(processed_c171_classes))
# base_cls = list(set(CLASSES150) & set(processed_c171_classes))
# len(base_cls), len(novel_cls), len(all_cls)
# import json

# json.dump(all_cls, open("../files/ade150ucoco.json", "w"))

# %%
cityscapes = ('road', 'sidewalk', 'building', 'wall', 'fence', 'pole',
               'traffic light', 'traffic sign', 'vegetation', 'terrain', 'sky',
               'person', 'rider', 'car', 'truck', 'bus', 'train', 'motorcycle',
               'bicycle')
novel_cls = list(set(CLASSES150) - set(cityscapes))
base_cls = list(set(CLASSES150) & set(cityscapes))

def _log(metric):
    import numpy as np
    metrics = [x.strip() for x in metric.split("\n")]
    ious = {}
    accs = {}
    for i in range(len(metrics)):
        k, iou, acc = metrics[i].split("|")[1:-1]
        ious[k.strip()] = float(iou.strip())
        accs[k.strip()] = float(acc.strip())
    ious_base = [v for k, v in ious.items() if k in base_cls]
    ious_novel = [v for k, v in ious.items() if k in novel_cls]
    accs_base = [v for k, v in accs.items() if k in base_cls]
    accs_novel = [v for k, v in accs.items() if k in novel_cls]
    print(f"seen: mIoU {np.mean(ious_base):.2f}, mAcc {np.mean(accs_base):.2f}")
    print(f"unseen: mIoU {np.mean(ious_novel):.2f}, mAcc {np.mean(accs_novel):.2f}")

# %%
_log("""|         wall        | 40.97 | 54.58 |
|       building      | 59.81 | 67.02 |
|         sky         | 58.44 | 94.98 |
|        floor        | 32.81 | 54.06 |
|         tree        | 40.67 | 70.57 |
|       ceiling       | 40.96 | 61.85 |
|         road        |  60.9 |  67.7 |
|         bed         | 48.99 | 71.79 |
|      windowpane     | 37.06 | 50.92 |
|        grass        | 23.39 | 28.43 |
|       cabinet       | 34.37 | 41.51 |
|       sidewalk      | 28.54 |  33.8 |
|        person       | 26.72 | 97.53 |
|        earth        |  3.74 |  4.1  |
|         door        | 21.95 | 25.34 |
|        table        | 20.64 | 30.14 |
|       mountain      | 32.63 | 44.79 |
|        plant        |  30.6 | 45.62 |
|       curtain       | 55.02 | 71.78 |
|        chair        | 21.05 | 39.83 |
|         car         | 48.07 | 92.95 |
|        water        |  7.32 |  8.6  |
|       painting      | 31.81 | 70.81 |
|         sofa        | 34.17 | 41.64 |
|        shelf        | 14.91 | 17.74 |
|        house        |  2.87 |  3.13 |
|         sea         |  31.5 | 50.33 |
|        mirror       | 28.86 | 41.08 |
|         rug         |  37.2 |  40.5 |
|        field        |  8.53 |  9.5  |
|       armchair      |  8.34 |  8.63 |
|         seat        | 37.88 | 47.94 |
|        fence        | 23.98 |  43.3 |
|         desk        | 12.74 | 16.92 |
|         rock        | 20.51 | 30.81 |
|       wardrobe      | 34.24 | 38.49 |
|         lamp        | 11.93 | 62.18 |
|       bathtub       | 42.01 | 49.83 |
|       railing       | 16.42 | 18.25 |
|       cushion       | 32.47 | 46.72 |
|         base        |  2.21 |  2.29 |
|         box         |  9.13 |  11.4 |
|        column       | 31.14 | 44.91 |
|      signboard      | 16.98 | 26.91 |
|   chest of drawers  | 23.54 | 30.86 |
|       counter       | 11.89 | 12.35 |
|         sand        | 12.09 | 12.99 |
|         sink        | 26.14 | 60.33 |
|      skyscraper     | 34.22 |  39.6 |
|      fireplace      | 32.93 | 73.98 |
|     refrigerator    | 51.28 | 67.12 |
|      grandstand     | 24.82 | 42.45 |
|         path        |  1.01 |  1.03 |
|        stairs       |  0.67 |  0.71 |
|        runway       | 19.26 | 20.34 |
|         case        | 41.32 | 48.84 |
|      pool table     | 66.52 | 96.99 |
|        pillow       | 10.47 | 11.79 |
|     screen door     |  11.2 | 11.75 |
|       stairway      | 22.15 |  29.0 |
|        river        |  4.36 |  4.83 |
|        bridge       | 16.18 | 19.36 |
|       bookcase      |  12.7 | 15.66 |
|        blind        |  6.36 |  6.65 |
|     coffee table    | 15.68 | 18.13 |
|        toilet       | 43.35 | 86.57 |
|        flower       | 21.43 | 47.19 |
|         book        | 27.61 | 60.33 |
|         hill        |  0.56 |  0.59 |
|        bench        | 24.02 | 39.63 |
|      countertop     |  0.49 |  0.49 |
|        stove        | 42.19 | 55.09 |
|         palm        | 28.65 |  79.6 |
|    kitchen island   |  0.0  |  0.0  |
|       computer      | 41.38 | 50.68 |
|     swivel chair    | 26.31 | 33.08 |
|         boat        | 26.15 | 39.51 |
|         bar         | 14.98 |  16.6 |
|    arcade machine   |  3.19 |  3.24 |
|        hovel        | 10.28 | 10.51 |
|         bus         | 77.85 | 94.08 |
|        towel        | 48.84 | 71.29 |
|        light        |  4.06 | 24.35 |
|        truck        | 36.35 |  51.0 |
|        tower        |  2.91 |  3.15 |
|      chandelier     | 37.27 | 77.96 |
|        awning       | 12.98 | 15.94 |
|     streetlight     |  12.6 | 26.81 |
|        booth        |  1.26 |  1.28 |
| television receiver |  33.1 | 64.76 |
|       airplane      | 22.16 |  50.2 |
|      dirt track     |  2.93 |  3.32 |
|       apparel       | 26.64 | 46.42 |
|         pole        | 17.89 | 57.14 |
|         land        |  0.03 |  0.03 |
|      bannister      |  2.9  |  3.54 |
|      escalator      |  6.33 |  6.52 |
|       ottoman       |  3.56 |  3.64 |
|        bottle       | 16.95 | 72.61 |
|        buffet       |  0.0  |  0.0  |
|        poster       |  0.63 |  0.65 |
|        stage        |  7.72 | 14.12 |
|         van         |  0.01 |  0.01 |
|         ship        |  1.91 |  1.91 |
|       fountain      | 24.86 | 25.56 |
|    conveyer belt    | 59.72 | 60.92 |
|        canopy       |  0.21 |  0.22 |
|        washer       | 41.13 | 42.69 |
|      plaything      | 18.07 | 25.91 |
|    swimming pool    |  34.7 | 38.43 |
|        stool        | 24.33 | 32.77 |
|        barrel       | 33.62 | 55.97 |
|        basket       |  7.12 |  8.89 |
|      waterfall      |  43.7 | 76.41 |
|         tent        | 47.42 | 51.28 |
|         bag         |  2.5  |  2.95 |
|       minibike      | 47.73 | 82.29 |
|        cradle       | 42.85 | 84.15 |
|         oven        |  0.0  |  0.0  |
|         ball        | 35.19 | 54.23 |
|         food        |  7.65 |  8.15 |
|         step        |  0.0  |  0.0  |
|         tank        | 19.63 | 20.11 |
|      trade name     |  1.19 |  1.25 |
|      microwave      | 64.81 | 79.05 |
|         pot         |  0.97 |  1.03 |
|        animal       | 27.32 | 42.94 |
|       bicycle       | 22.68 | 93.57 |
|         lake        |  0.05 |  0.05 |
|      dishwasher     |  0.0  |  0.0  |
|        screen       | 49.64 | 80.54 |
|       blanket       |  0.0  |  0.0  |
|      sculpture      | 40.35 | 46.24 |
|         hood        | 30.52 |  35.0 |
|        sconce       |  5.4  | 17.36 |
|         vase        |  9.56 | 14.27 |
|    traffic light    | 22.78 | 34.64 |
|         tray        |  3.78 |  9.7  |
|        ashcan       | 19.35 | 23.52 |
|         fan         | 13.03 | 37.63 |
|         pier        |  2.5  |  5.33 |
|      crt screen     |  0.9  |  0.91 |
|        plate        | 26.21 |  46.3 |
|       monitor       | 25.97 | 32.12 |
|    bulletin board   | 21.54 | 24.27 |
|        shower       |  0.0  |  0.0  |
|       radiator      |  22.3 | 22.89 |
|        glass        |  5.25 |  5.56 |
|        clock        |  6.99 | 23.04 |
|         flag        | 10.95 | 31.96 |""")
# Out:
# seen: mIoU 40.38, mAcc 67.87
# unseen: mIoU 20.41, mAcc 30.79

# %% [markdown]
# # Sample Images for Visualization

# %%
with open("/mnt/haojun/itpsea4data/dataset/imagenet22k_azcopy/ImageNet130.txt", "r") as f:
    lines = f.readlines()

# %%
images = {}
for line in lines:
    img_id = line.strip()
    cls_id = img_id.split("_")[0]
    if cls_id not in images:
        images[cls_id] = []
    images[cls_id].append(img_id)

# %%
import numpy as np
with open("/mnt/haojun/itpsea4data/dataset/imagenet22k_azcopy/ImageNet130_vis20.txt", "w") as f:
    for cls_id in images:
        imgs = images[cls_id]
        inds = np.random.choice(range(len(imgs)), size=20, replace=False)
        for ind in inds:
            print(imgs[ind], file=f)

# %%
a150_classes = (
    'wall', 'building', 'sky', 'floor', 'tree', 'ceiling', 'road', 'bed',
    'windowpane', 'grass', 'cabinet', 'sidewalk', 'person', 'earth',
    'door', 'table', 'mountain', 'plant', 'curtain', 'chair', 'car',
    'water', 'painting', 'sofa', 'shelf', 'house', 'sea', 'mirror', 'rug',
    'field', 'armchair', 'seat', 'fence', 'desk', 'rock', 'wardrobe',
    'lamp', 'bathtub', 'railing', 'cushion', 'base', 'box', 'column',
    'signboard', 'chest of drawers', 'counter', 'sand', 'sink',
    'skyscraper', 'fireplace', 'refrigerator', 'grandstand', 'path',
    'stairs', 'runway', 'case', 'pool table', 'pillow', 'screen door',
    'stairway', 'river', 'bridge', 'bookcase', 'blind', 'coffee table',
    'toilet', 'flower', 'book', 'hill', 'bench', 'countertop', 'stove',
    'palm', 'kitchen island', 'computer', 'swivel chair', 'boat', 'bar',
    'arcade machine', 'hovel', 'bus', 'towel', 'light', 'truck', 'tower',
    'chandelier', 'awning', 'streetlight', 'booth', 'television receiver',
    'airplane', 'dirt track', 'apparel', 'pole', 'land', 'bannister',
    'escalator', 'ottoman', 'bottle', 'buffet', 'poster', 'stage', 'van',
    'ship', 'fountain', 'conveyer belt', 'canopy', 'washer', 'plaything',
    'swimming pool', 'stool', 'barrel', 'basket', 'waterfall', 'tent',
    'bag', 'minibike', 'cradle', 'oven', 'ball', 'food', 'step', 'tank',
    'trade name', 'microwave', 'pot', 'animal', 'bicycle', 'lake',
    'dishwasher', 'screen', 'blanket', 'sculpture', 'hood', 'sconce',
    'vase', 'traffic light', 'tray', 'ashcan', 'fan', 'pier', 'crt screen',
    'plate', 'monitor', 'bulletin board', 'shower', 'radiator', 'glass',
    'clock', 'flag')

c171_classes = (
    'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train',
    'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep',
    'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard',
    'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard',
    'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork',
    'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange',
    'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair',
    'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv',
    'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave',
    'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase',
    'scissors', 'teddy bear', 'hair drier', 'toothbrush', 'banner',
    'blanket', 'branch', 'bridge', 'building-other', 'bush', 'cabinet',
    'cage', 'cardboard', 'carpet', 'ceiling-other', 'ceiling-tile',
    'cloth', 'clothes', 'clouds', 'counter', 'cupboard', 'curtain',
    'desk-stuff', 'dirt', 'door-stuff', 'fence', 'floor-marble',
    'floor-other', 'floor-stone', 'floor-tile', 'floor-wood',
    'flower', 'fog', 'food-other', 'fruit', 'furniture-other', 'grass',
    'gravel', 'ground-other', 'hill', 'house', 'leaves', 'light', 'mat',
    'metal', 'mirror-stuff', 'moss', 'mountain', 'mud', 'napkin', 'net',
    'paper', 'pavement', 'pillow', 'plant-other', 'plastic', 'platform',
    'playingfield', 'railing', 'railroad', 'river', 'road', 'rock', 'roof',
    'rug', 'salad', 'sand', 'sea', 'shelf', 'sky-other', 'skyscraper',
    'snow', 'solid-other', 'stairs', 'stone', 'straw', 'structural-other',
    'table', 'tent', 'textile-other', 'towel', 'tree', 'vegetable',
    'wall-brick', 'wall-concrete', 'wall-other', 'wall-panel',
    'wall-stone', 'wall-tile', 'wall-wood', 'water-other', 'waterdrops',
    'window-blind', 'window-other', 'wood')

processed_c171_classes = (
    'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train',
    'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep',
    'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard',
    'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard',
    'surfboard', 'tennis racket', 'bottle', 'glass', 'cup', 'fork',
    'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange',
    'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair',
    'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'television receiver',
    'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave',
    'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase',
    'scissors', 'teddy bear', 'hair drier', 'toothbrush', 'banner',
    'blanket', 'branch', 'bridge', 'building', 'bush', 'cabinet',
    'cage', 'cardboard', 'carpet', 'ceiling', 'ceiling',
    'cloth', 'clothes', 'clouds', 'counter', 'cupboard', 'curtain',
    'desk', 'dirt track', 'door', 'fence', 'floor',
    'floor', 'floor', 'floor', 'floor',
    'flower', 'fog', 'food', 'fruit', 'furniture', 'grass',
    'gravel', 'ground', 'hill', 'house', 'leaves', 'light', 'mat',
    'metal', 'mirror', 'moss', 'mountain', 'mud', 'napkin', 'net',
    'paper', 'pavement', 'pillow', 'plant', 'plastic', 'platform',
    'playingfield', 'railing', 'railroad', 'river', 'road', 'rock', 'roof',
    'rug', 'salad', 'sand', 'sea', 'shelf', 'sky', 'skyscraper',
    'snow', 'solid', 'stairs', 'stone', 'straw', 'structural',
    'table', 'tent', 'textile', 'towel', 'tree', 'vegetable',
    'wall', 'wall', 'wall', 'wall',
    'wall', 'wall', 'wall', 'water', 'waterdrops',
    'blind', 'windowpane', 'wood')

# a150_c171 = list(set(a150_classes) - set(processed_c171_classes))
# inter_cls = list(set(processed_c171_classes) & set(a150_classes))
# c171_a150 = [c171_classes[i] for i in range(len(c171_classes)) if processed_c171_classes[i] not in inter_cls]

# %%
# import json

# json.dump(a150_c171, open("a150-c171.json", "w"))

# %%
# import json

# json.dump(c171_a150, open("c171-a150.json", "w"))

# %%
# c171ua150 = list(set(a150_classes) | set(c171_classes))
# import json

# json.dump(c171_a150, open("coco171uade150.json", "w"))

# %%
ade_splits = [
    [1, 3, 6, 8, 10, 13, 17, 22, 23, 29, 33, 38, 41, 50, 51, 56, 67, 70, 71, 74, 77, 81, 92, 93, 98,
    101, 102, 103, 110, 113, 119, 121, 126, 127, 130, 136, 147, 149],

    [0, 10, 21, 27, 28, 29, 34, 40, 42, 43, 51, 57, 58, 65, 66, 68, 69, 73, 76, 78, 85, 88, 90, 100,
    105, 110, 111, 112, 113, 114, 117, 123, 124, 132, 134, 139, 142, 146],

    [0, 5, 9, 15, 16, 21, 24, 25, 27, 32, 34, 35, 38, 39, 55, 70, 76, 85, 95, 96, 98, 100, 106, 109,
    111, 118, 119, 124, 128, 132, 134, 135, 136, 138, 140, 141, 143, 144],
    
    [5, 11, 13, 16, 21, 24, 26, 32, 35, 42, 53, 56, 60, 61, 63, 64, 68, 70, 75, 82, 91, 93, 94, 99, 100,
    105, 111, 115, 118, 121, 122, 130, 132, 135, 137, 138, 141, 143]
]

def _log_splits(metric, split):
    import numpy as np
    metrics = [x.strip() for x in metric.split("\n")]
    ious_novel = []
    accs_novel = []
    ious_base = []
    accs_base = []

    for i in range(len(metrics)):
        k, iou, acc = metrics[i].split("|")[1:-1]
        if i in ade_splits[split]:
            ious_novel.append(float(iou.strip()))
            accs_novel.append(float(acc.strip()))
        else:
            ious_base.append(float(iou.strip()))
            accs_base.append(float(acc.strip()))
    print(f"seen: mIoU {np.mean(ious_base):.2f}, mAcc {np.mean(accs_base):.2f}")
    print(f"unseen: mIoU {np.mean(ious_novel):.2f}, mAcc {np.mean(accs_novel):.2f}")

# %%
a = """|         wall        | 49.61 |  53.3 |
|       building      | 78.46 | 90.51 |
|         sky         | 92.57 | 97.56 |
|        floor        | 75.48 | 90.06 |
|         tree        | 70.83 | 86.27 |
|       ceiling       | 60.07 | 76.74 |
|         road        | 78.95 |  90.6 |
|         bed         | 79.86 | 95.83 |
|      windowpane     | 51.65 |  81.9 |
|        grass        | 55.72 | 62.66 |
|       cabinet       | 44.74 | 74.03 |
|       sidewalk      |  53.2 | 65.53 |
|        person       | 75.56 | 92.48 |
|        earth        | 38.03 | 62.39 |
|         door        | 29.89 |  70.8 |
|        table        | 22.45 | 29.95 |
|       mountain      |  49.0 | 58.41 |
|        plant        | 46.91 | 57.93 |
|       curtain       | 64.85 | 80.39 |
|        chair        | 46.36 | 67.98 |
|         car         |  79.8 | 89.42 |
|        water        | 33.98 | 42.37 |
|       painting      | 48.67 | 90.06 |
|         sofa        | 54.07 | 77.43 |
|        shelf        | 22.44 | 27.37 |
|        house        | 24.94 | 27.18 |
|         sea         | 56.21 | 89.41 |
|        mirror       | 33.62 | 44.51 |
|         rug         | 56.49 | 61.09 |
|        field        | 22.91 | 53.06 |
|       armchair      | 30.04 | 43.66 |
|         seat        | 60.95 | 80.06 |
|        fence        | 35.59 | 60.44 |
|         desk        | 27.17 | 65.51 |
|         rock        | 36.85 | 50.36 |
|       wardrobe      |  33.6 | 37.57 |
|         lamp        | 37.65 | 78.19 |
|       bathtub       | 56.31 | 79.67 |
|       railing       | 25.52 | 36.72 |
|       cushion       | 14.53 |  24.8 |
|         base        | 22.67 | 39.88 |
|         box         | 19.09 | 34.52 |
|        column       | 36.38 | 62.59 |
|      signboard      | 24.57 | 50.97 |
|   chest of drawers  | 28.78 | 48.93 |
|       counter       |  25.9 | 58.47 |
|         sand        | 35.59 | 51.95 |
|         sink        | 55.51 | 74.33 |
|      skyscraper     | 44.75 | 49.13 |
|      fireplace      | 52.63 | 78.28 |
|     refrigerator    | 52.69 | 72.77 |
|      grandstand     |  41.3 | 69.33 |
|         path        |  8.01 |  8.6  |
|        stairs       | 34.36 | 44.64 |
|        runway       | 71.23 | 91.91 |
|         case        | 43.52 | 54.98 |
|      pool table     | 88.07 | 96.06 |
|        pillow       | 40.02 | 59.15 |
|     screen door     | 39.26 | 84.22 |
|       stairway      | 34.82 | 45.93 |
|        river        | 15.06 | 56.49 |
|        bridge       | 50.63 | 67.22 |
|       bookcase      | 30.18 | 62.76 |
|        blind        | 31.91 |  37.6 |
|     coffee table    | 40.79 | 80.66 |
|        toilet       | 71.73 | 88.41 |
|        flower       | 31.78 | 52.84 |
|         book        | 40.71 | 62.96 |
|         hill        |  5.5  |  8.96 |
|        bench        | 39.76 | 53.26 |
|      countertop     | 19.43 | 22.45 |
|        stove        | 49.93 | 67.61 |
|         palm        | 43.01 | 57.95 |
|    kitchen island   | 25.61 | 82.76 |
|       computer      | 52.82 | 75.13 |
|     swivel chair    | 37.88 | 68.35 |
|         boat        | 45.22 | 58.42 |
|         bar         | 44.97 | 60.52 |
|    arcade machine   | 32.14 | 35.01 |
|        hovel        | 35.57 | 67.57 |
|         bus         | 75.36 | 90.11 |
|        towel        | 49.66 | 79.65 |
|        light        | 27.15 | 78.69 |
|        truck        | 27.65 | 36.46 |
|        tower        | 13.44 | 19.79 |
|      chandelier     | 20.54 | 56.15 |
|        awning       | 26.66 | 33.04 |
|     streetlight     | 12.99 | 15.21 |
|        booth        | 27.28 | 52.24 |
| television receiver | 58.85 | 79.39 |
|       airplane      | 53.56 | 64.79 |
|      dirt track     |  2.04 |  5.35 |
|       apparel       | 36.58 | 71.23 |
|         pole        |  12.0 | 14.98 |
|         land        |  5.43 |  7.79 |
|      bannister      |  5.77 | 10.53 |
|      escalator      | 20.22 | 24.86 |
|       ottoman       | 28.92 | 31.71 |
|        bottle       |  9.38 | 40.19 |
|        buffet       | 40.65 |  52.7 |
|        poster       |  1.86 |  2.3  |
|        stage        |  6.34 |  11.7 |
|         van         | 33.01 | 49.29 |
|         ship        |  50.8 | 84.16 |
|       fountain      | 19.69 | 21.11 |
|    conveyer belt    | 47.91 | 93.34 |
|        canopy       | 17.76 | 20.16 |
|        washer       | 68.55 | 74.53 |
|      plaything      | 27.13 | 54.96 |
|    swimming pool    | 35.31 | 48.71 |
|        stool        | 20.82 | 27.22 |
|        barrel       | 50.16 | 70.95 |
|        basket       | 28.95 | 40.18 |
|      waterfall      | 62.99 |  86.1 |
|         tent        | 68.78 |  98.3 |
|         bag         |  9.55 | 11.07 |
|       minibike      | 62.76 | 75.25 |
|        cradle       | 64.98 | 88.32 |
|         oven        |  0.03 |  0.04 |
|         ball        | 35.65 | 70.26 |
|         food        | 53.79 | 79.44 |
|         step        |  6.34 |  8.49 |
|         tank        | 46.12 | 62.72 |
|      trade name     | 11.07 | 11.87 |
|      microwave      | 42.42 | 62.91 |
|         pot         | 30.31 | 35.95 |
|        animal       | 71.68 | 80.37 |
|       bicycle       | 52.26 |  72.7 |
|         lake        |  0.0  |  0.0  |
|      dishwasher     | 32.31 | 67.64 |
|        screen       | 49.66 | 88.39 |
|       blanket       |  3.85 |  4.58 |
|      sculpture      | 36.68 | 57.67 |
|         hood        | 38.97 | 59.25 |
|        sconce       |  6.07 | 22.85 |
|         vase        |  1.36 |  8.43 |
|    traffic light    | 11.97 |  67.0 |
|         tray        |  7.99 | 13.85 |
|        ashcan       |  9.71 | 55.86 |
|         fan         |  32.3 | 74.92 |
|         pier        | 24.15 |  39.1 |
|      crt screen     |  0.2  |  0.48 |
|        plate        | 43.66 | 76.36 |
|       monitor       |  3.67 |  4.17 |
|    bulletin board   |  2.67 |  3.65 |
|        shower       |  0.1  |  0.38 |
|       radiator      | 46.03 | 63.14 |
|        glass        | 13.79 | 18.27 |
|        clock        | 20.31 | 25.37 |
|         flag        | 47.07 | 58.35 |"""

_log_splits(a, 2)
# Out:
# seen: mIoU 40.82, mAcc 59.56
# unseen: mIoU 24.78, mAcc 37.75
