# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
img = Image.open("result/demo_sky_palace_river_tree.png")
img = np.array(img)
img.shape
# Out:
# (420, 770)

# %%
plt.imshow(np.array(img))

# %%
np.unique(np.array(img))
# Out:
# array([1, 2, 3], dtype=uint8)

# %%
from glob import glob

annos = glob("/workspace/dataset/A150/annotations/validation/*.png")

# %%
CLASSES = [
        'wall', 'building', 'sky', 'floor', 'tree', 'ceiling', 'road', 'bed',
        'windowpane', 'grass', 'cabinet', 'sidewalk', 'person', 'earth',
        'door', 'table', 'mountain', 'plant', 'curtain', 'chair', 'car',
        'water', 'painting', 'sofa', 'shelf', 'house', 'sea', 'mirror', 'rug',
        'field', 'armchair', 'seat', 'fence', 'desk', 'rock', 'wardrobe',
        'lamp', 'bathtub', 'railing', 'cushion', 'base', 'box', 'column',
        'signboard', 'chest of drawers', 'counter', 'sand', 'sink',
        'skyscraper', 'fireplace', 'refrigerator', 'grandstand', 'path',
        'stairs', 'runway', 'case', 'pool table', 'pillow', 'screen door',
        'stairway', 'river', 'bridge', 'bookcase', 'blind', 'coffee table',
        'toilet', 'flower', 'book', 'hill', 'bench', 'countertop', 'stove',
        'palm', 'kitchen island', 'computer', 'swivel chair', 'boat', 'bar',
        'arcade machine', 'hovel', 'bus', 'towel', 'light', 'truck', 'tower',
        'chandelier', 'awning', 'streetlight', 'booth', 'television receiver',
        'airplane', 'dirt track', 'apparel', 'pole', 'land', 'bannister',
        'escalator', 'ottoman', 'bottle', 'buffet', 'poster', 'stage', 'van',
        'ship', 'fountain', 'conveyer belt', 'canopy', 'washer', 'plaything',
        'swimming pool', 'stool', 'barrel', 'basket', 'waterfall', 'tent',
        'bag', 'minibike', 'cradle', 'oven', 'ball', 'food', 'step', 'tank',
        'trade name', 'microwave', 'pot', 'animal', 'bicycle', 'lake',
        'dishwasher', 'screen', 'blanket', 'sculpture', 'hood', 'sconce',
        'vase', 'traffic light', 'tray', 'ashcan', 'fan', 'pier', 'crt screen',
        'plate', 'monitor', 'bulletin board', 'shower', 'radiator', 'glass',
        'clock', 'flag']
CLASSES.index("armchair"), CLASSES.index("swivel chair")
# Out:
# (30, 75)

# %%
for a in annos:
    x = np.array(Image.open(a))
    if 30 in x and 75 in x:
        print(a)
# Out:
# /workspace/dataset/A150/annotations/validation/ADE_val_00000038.png
# /workspace/dataset/A150/annotations/validation/ADE_val_00000298.png
# /workspace/dataset/A150/annotations/validation/ADE_val_00001037.png
# /workspace/dataset/A150/annotations/validation/ADE_val_00001498.png
# /workspace/dataset/A150/annotations/validation/ADE_val_00001958.png

# %%
img = np.array(
    Image.open("/workspace/dataset/A150/annotations_hypernym/validation/ADE_val_00001958.png"))

# %%
ADE20K_SEM_SEG_HYPER_CATEGORIES = (
    "air_craft, airplane", "platform, horizontal surface, stage", "angiosperm, flowering plant, flower", "plate", "timepiece, clock", "table, desk, counter", "lighting fixture, chandelier", "kitchen appliance, oven, microwave", "public transport, bus", "human, person", "fan", "white goods, refrigerator, washer, dishwasher", "shower", "cushion, pillow", "truck, van", "heater, stove", "shelter, canopy", "substance, food", "wheeled vehicle", "cloth, curtain", "gramineous plant", "furniture", "canopy, awning", "mechanism radiator", "cloth, flag", "machine, electronic equipment, computer", "organism, plant, animal", "partition, wall", "woody plant", "way, road, path", "edition, printed work, book", "pool, swimming pool", "water craft", "electronic equipment, monitor", "receptacle, container, tray", "vessel, bathtub, bottle, barrel, tank", "land, floor", "jar, vessel, vase", "source of illumination, lamp, light", "glass, surface, windowpane", "water", "earth, land", "container, ashcan", "floor cover", "sink", "traffic signal, light, traffic light", "natural object, rock", "natural elevation, mountain", "chair", "bracket, sconce", "structure, building, door, signboard, grandstand, bridge, tower, fountain, trade name", "seat", "protective_covering blind", "body_of_water sea", "door", "container, box, case, basket, bag, pot, drinking glass", "clothing, apparel", "bar", "paved surface", "support, shelf, seat, base, stairway, escalator, pier", "shelter, hovel, tent", "atmosphere", "arcade", "tree", "cloth, fabric, towel", "lamp, light, streetlight", "room, toilet, kitchen island", "game equipment, pool table, ball", "hood", "soil, sand", "bedroom furniture", "motor vehicle", "conveyer belt", "fireplace", "earth, dirt", "reflector, mirror", "baby bed", "upper surface, ceiling", "shop, booth", "barrier, fence, railing, bannister", "bedclothes, blanket", "display, screen", "geographical area, field", "walk, sidewalk", "plastic art, sculpture", "receiver", "upright, column, pole", "building", "painting", "countertop", "poster", "silver screen", "bulletin board"
)
unique_label = np.unique(img)
for l in unique_label:
    print(ADE20K_SEM_SEG_HYPER_CATEGORIES[int(l)])
    plt.imshow(img == int(l))
    plt.show()
# Out:
# table, desk, counter
# cushion, pillow
# cloth, curtain
# machine, electronic equipment, computer
# partition, wall
# land, floor
# source of illumination, lamp, light
# glass, surface, windowpane
# chair
# structure, building, door, signboard, grandstand, bridge, tower, fountain, trade name
# protective_covering blind
# upper surface, ceiling
# painting
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-1457f3cd7fbf> in <module>
#       4 unique_label = np.unique(img)
#       5 for l in unique_label:
# ----> 6     print(ADE20K_SEM_SEG_HYPER_CATEGORIES[int(l)])
#       7     plt.imshow(img == int(l))
#       8     plt.show()
#
# IndexError: tuple index out of range
